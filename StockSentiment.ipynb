# %%
# !pip install requests transformers pandas datetime vaderSentiment requests yfinance finnhub-python
# !pip install nltk
# !pip install vaderSentiment
# !pip install yahoo-fin
# !pip install finvizfinance
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.41)
# Collecting finnhub-python
#   Downloading finnhub_python-2.4.20-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (71.0.4)
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.2 MB/s eta 0:00:00
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 5.1 MB/s eta 0:00:00
# Downloading finnhub_python-2.4.20-py3-none-any.whl (11 kB)
# Downloading zope.interface-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: zope.interface, vaderSentiment, finnhub-python, datetime
# Successfully installed datetime-5.5 finnhub-python-2.4.20 vaderSentiment-3.3.2 zope.interface-7.0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.7.4)
# Collecting yahoo-fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl.metadata (699 bytes)
# Collecting requests-html (from yahoo-fin)
#   Downloading requests_html-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting feedparser (from yahoo-fin)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo-fin) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo-fin) (2.1.4)
# Collecting sgmllib3k (from feedparser->yahoo-fin)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo-fin) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo-fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo-fin) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo-fin) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo-fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo-fin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo-fin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo-fin) (2024.7.4)
# Collecting pyquery (from requests-html->yahoo-fin)
#   Downloading pyquery-2.0.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting fake-useragent (from requests-html->yahoo-fin)
#   Downloading fake_useragent-1.5.1-py3-none-any.whl.metadata (15 kB)
# Collecting parse (from requests-html->yahoo-fin)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting bs4 (from requests-html->yahoo-fin)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting w3lib (from requests-html->yahoo-fin)
#   Downloading w3lib-2.2.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->yahoo-fin)
#   Downloading pyppeteer-2.0.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer>=0.0.14->requests-html->yahoo-fin)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (8.2.0)
# Collecting pyee<12.0.0,>=11.0.0 (from pyppeteer>=0.0.14->requests-html->yahoo-fin)
#   Downloading pyee-11.1.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (4.66.4)
# Collecting urllib3<3,>=1.21.1 (from requests->yahoo-fin)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 1.9 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo-fin)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->yahoo-fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo-fin) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo-fin) (4.9.4)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->yahoo-fin)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo-fin) (3.19.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo-fin) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo-fin) (2.5)
# Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.4 MB/s eta 0:00:00
# Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Downloading pyppeteer-2.0.0-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.6 MB/s eta 0:00:00
# Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 8.6 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Downloading w3lib-2.2.1-py3-none-any.whl (21 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.7 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=558a8fd99e49806363b6e943be3180cff6f44ab52847892f8bc81b340cc64f40
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, parse, fake-useragent, appdirs, websockets, w3lib, urllib3, pyee, feedparser, cssselect, pyquery, pyppeteer, bs4, requests-html, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed appdirs-1.4.4 bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.5.1 feedparser-6.0.11 parse-1.20.2 pyee-11.1.0 pyppeteer-2.0.0 pyquery-2.0.0 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.26.19 w3lib-2.2.1 websockets-10.4 yahoo-fin-0.8.9.1
# Collecting finvizfinance
#   Downloading finvizfinance-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from finvizfinance) (2.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from finvizfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from finvizfinance) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finvizfinance) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->finvizfinance) (2.5)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->finvizfinance) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->finvizfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->finvizfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->finvizfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->finvizfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->finvizfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->finvizfinance) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->finvizfinance) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->finvizfinance) (1.16.0)
# Downloading finvizfinance-1.0.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: finvizfinance
# Successfully installed finvizfinance-1.0.1

# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta
import pytz
from io import StringIO
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer as NLTKSentimentIntensityAnalyzer
import os
from yahoo_fin import news as yahoo_fin_news
from finvizfinance.quote import finvizfinance
import logging

# Initialize logger
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Download necessary NLTK data
nltk.download('vader_lexicon')
nltk.download('movie_reviews')
nltk.download('punkt')

# Function to convert Unix timestamp to human-readable datetime in Eastern Time
def convert_unix_to_datetime(unix_timestamp):
    eastern = pytz.timezone('US/Eastern')
    utc_time = datetime.utcfromtimestamp(unix_timestamp)
    eastern_time = utc_time.replace(tzinfo=pytz.utc).astimezone(eastern)
    return eastern_time

# Function to perform sentiment analysis using VADER
def analyze_vader_sentiment(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(text)
    return sentiment_score['compound']

# Function to perform sentiment analysis using NLTK
def analyze_nltk_sentiment(text):
    sia = NLTKSentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)
    return sentiment_score['compound']

# Function to store news data in a DataFrame and append to CSV
def store_news_data(ticker, headline, summary, datetime_obj, vader_sentiment, nltk_sentiment, csv_file):
    new_data = {
        'ticker': ticker,
        'headline': headline,
        'summary': summary,
        'datetime': datetime_obj.strftime('%Y-%m-%d %H:%M:%S'),
        'vader_sentiment': vader_sentiment,
        'nltk_sentiment': nltk_sentiment
    }
    df = pd.DataFrame([new_data], columns=['ticker', 'headline', 'summary', 'datetime', 'vader_sentiment', 'nltk_sentiment'])

    # Append data to CSV file
    header = not os.path.isfile(csv_file)
    df.to_csv(csv_file, mode='a', header=header, index=False)

# Function to fetch the latest news for a given stock ticker
def get_latest_news(ticker: str, source: str = 'yf') -> list:
    """
    Fetches the latest news for a given stock ticker using either the yahoo_fin or finviz library.

    :param ticker: The stock ticker symbol.
    :param source: The news source to fetch from. Options are 'yf' for yahoo_fin and 'finviz' for finvizfinance.
                   Default value is 'yf'.
    :return: A list of latest news articles with their titles and URLs.
    """
    news_list = []
    try:
        if source == 'yf':
            logger.info(f'Fetching latest news for {ticker} from Yahoo! Finance')
            news_data = yahoo_fin_news.get_yf_rss(ticker)
            for article in news_data:
                news_list.append({
                    "ticker": ticker,
                    "title": article["title"],
                    "summary": article["summary"],
                    "url": article["link"],
                    "time": article["published"]
                })
        elif source == 'finviz':
            logger.info(f'Fetching latest news for {ticker} from Finviz')
            news_data = finvizfinance(ticker).ticker_news()
            for index, row in news_data.iterrows():
                news_list.append({
                    "ticker": ticker,
                    "title": row["Title"],
                    "summary": None,
                    "url": row["Link"],
                    "time": row["Date"]
                })
        else:
            raise ValueError("Invalid news source. Please choose either 'yf' or 'finviz'.")

        return news_list

    except Exception as e:
        logger.error(f"An error occurred: {e}")
        return []

# Function to fetch recent news within the last hour and check for duplicates
def fetch_recent_news(tickers, csv_file, source='yf'):
    eastern = pytz.timezone('US/Eastern')
    now = datetime.now(eastern)
    from_time = now - timedelta(minutes=1)
    print(f"Fetching news for tickers: {tickers}")

    # Load existing headlines from CSV
    if os.path.isfile(csv_file):
        existing_data = pd.read_csv(csv_file)
        existing_headlines = set(existing_data['headline'])
    else:
        existing_headlines = set()

    new_news_found = []

    for ticker in tickers:
        news_list = get_latest_news(ticker, source)
        for article in news_list:
            headline = article["title"]
            if headline and headline not in existing_headlines:
                summary = article.get("summary", "")
                datetime_obj = datetime.strptime(article["time"], '%a, %d %b %Y %H:%M:%S %z').astimezone(eastern) if source == 'yf' else datetime.strptime(article["time"], '%b-%d-%y %I:%M%p').astimezone(eastern)
                if from_time <= datetime_obj <= now:
                    vader_sentiment = analyze_vader_sentiment(summary)
                    nltk_sentiment = analyze_nltk_sentiment(summary)
                    store_news_data(ticker, headline, summary, datetime_obj, vader_sentiment, nltk_sentiment, csv_file)
                    print(f"Fetched new news: {headline}")
                    new_news_found.append((ticker, datetime_obj))
                else:
                    print(f"News item '{headline}' is outside the desired time range. Skipping.")
            else:
                print(f"Skipped duplicate or empty headline news: {headline}")

    return new_news_found

# Function to fetch the data and extract stock prices
def fetch_stock_prices(url):
    response = requests.get(url)
    csv_content = response.content.decode('utf-8')
    df = pd.read_csv(StringIO(csv_content))
    prices = df[["Ticker", "Price"]]
    return prices

# Function to monitor stock prices for 5 minutes from the news release time
def monitor_stock_prices_for_news(news_csv_file, stock_csv_file):
    news_data = pd.read_csv(news_csv_file)

    for index, row in news_data.iterrows():
        ticker = row['ticker']
        news_time_str = row['datetime']
        news_time = datetime.strptime(news_time_str, '%Y-%m-%d %H:%M:%S')

        end_time = news_time + timedelta(minutes=5)
        url = f"https://elite.finviz.com/export.ashx?t={ticker}&auth=9fad0c6b-e75f-4e6d-a4a5-aae9838f9905"
        intervals = 5
        all_prices = []

        for i in range(intervals):
            try:
                current_time = datetime.now()
                if current_time > end_time:
                    break

                prices = fetch_stock_prices(url)
                prices["Time"] = current_time.strftime("%Y-%m-%d %H:%M:%S")
                all_prices.append(prices)
            except KeyError as e:
                print(f"Error: {e}")
            time.sleep(60)

        if all_prices:
            combined_prices = pd.concat(all_prices)
            combined_prices.reset_index(drop=True, inplace=True)
            combined_prices.sort_values(by=["Ticker", "Time"], inplace=True)

            first_prices = combined_prices.groupby('Ticker').first()['Price'].rename('First_Price')
            last_prices = combined_prices.groupby('Ticker').last()['Price'].rename('Last_Price')
            price_changes = last_prices - first_prices
            price_changes_df = price_changes.reset_index().rename(columns={0: 'Price_Change'})

            combined_prices = pd.merge(combined_prices, price_changes_df, on='Ticker')
            combined_prices.to_csv(stock_csv_file, mode='a', header=not os.path.isfile(stock_csv_file), index=False)

# Function to calculate the correlation between price changes and sentiments
def calculate_correlation(news_csv_file, stock_csv_file):
    news_data = pd.read_csv(news_csv_file)
    stock_data = pd.read_csv(stock_csv_file)

    merged_data = pd.merge(news_data, stock_data, on='ticker')
    correlation_vader = merged_data['Price_Change'].corr(merged_data['vader_sentiment'])
    correlation_nltk = merged_data['Price_Change'].corr(merged_data['nltk_sentiment'])

    print(f"Correlation between price change and VADER sentiment: {correlation_vader}")
    print(f"Correlation between price change and NLTK sentiment: {correlation_nltk}")

# Main function to run the monitoring process
def main():
    tickers = ["AAPL", "AMZN", "MSFT", "BYND", "TSLA", "GOOGL", "GOOG", "NVDA", "LMT", "PPG", "BABA", "W", "RCM", "WING", "UBER"]
    news_csv_file = "news_data.csv"
    stock_csv_file = "5_minute_stock_prices.csv"
    session = requests.Session()
    session.mount('https://', requests.adapters.HTTPAdapter(max_retries=5))

    while True:
        now = datetime.now(pytz.timezone('US/Eastern'))
        print(f"Fetching data at {now.strftime('%Y-%m-%d %H:%M:%S %Z')}")
        new_news_list = fetch_recent_news(tickers, news_csv_file, source='yf')  # Set source to 'yf' or 'finviz'
        if new_news_list:
            print(f"Fetched and processed news at {now.strftime('%Y-%m-%d %H:%M:%S %Z')}")
            monitor_stock_prices_for_news(news_csv_file, stock_csv_file)
            calculate_correlation(news_csv_file, stock_csv_file)
        else:
            print(f"No new news found at {now.strftime('%Y-%m-%d %H:%M:%S %Z')}")

        time.sleep(60)

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Streaming output truncated to the last 5000 lines.
# News item 'Oracle: Overvalued Despite AI Driving Fundamental Growth' is outside the desired time range. Skipping.
# News item 'Where Will Nvidia Stock Be in 5 Years?' is outside the desired time range. Skipping.
# News item 'AMD Stock Is a Buy Thanks to This Improving Metric' is outside the desired time range. Skipping.
# News item ''Magnificent Seven' rebounds, Nvidia leads the charge' is outside the desired time range. Skipping.
# News item 'Dow Jones Rallies 300 Points; Nvidia Partner Super Micro Plunges On Earnings (Live Coverage)' is outside the desired time range. Skipping.
# News item 'AI Stocks: Tech Giants, Cloud Titans Face 'Show Me' Moment' is outside the desired time range. Skipping.
# News item 'SoftBank’s Latest Big Purchase Could Be One of Its Best' is outside the desired time range. Skipping.
# News item 'Is It Too Late to Buy Dell Stock?' is outside the desired time range. Skipping.
# News item 'Dow Jones Futures Fuel New Market Rally On Bank Of Japan; Nvidia Partner Super Micro Dives' is outside the desired time range. Skipping.
# News item 'Successful Follow-Throughs Signal Market Bottoms, Offer Breakouts' is outside the desired time range. Skipping.
# News item 'Where Will Nvidia Stock Be in 1 Year?' is outside the desired time range. Skipping.
# News item 'What's in Store for Virgin Galactic (SPCE) in Q2 Earnings?' is outside the desired time range. Skipping.
# News item 'Lockheed Martin Insiders Sell US$13m Of Stock, Possibly Signalling Caution' is outside the desired time range. Skipping.
# News item 'Crypto sell-off, services PMI data, tech trends: Catalysts' is outside the desired time range. Skipping.
# News item 'Lockheed Martin's Sales Outlook Has Improved Investor Sentiment, RBC Says' is outside the desired time range. Skipping.
# News item 'Tyson Foods, Lockheed Martin, Kellanova: 3 stocks in focus' is outside the desired time range. Skipping.
# News item 'Lockheed Stock Is Up. Defense Is the Best Defense in an AI Stock Crunch.' is outside the desired time range. Skipping.
# News item 'Aerospace & Defense ETFs to Track Amid Q2 Earnings' is outside the desired time range. Skipping.
# News item 'Why Northrop Grumman Stock Shot Higher in July' is outside the desired time range. Skipping.
# News item 'Are Aerospace Stocks Lagging  Leidos (LDOS) This Year?' is outside the desired time range. Skipping.
# News item 'The Zacks Analyst Blog Highlights Toyota Motor, Lockheed Martin, Chubb and Pro-Dex' is outside the desired time range. Skipping.
# News item 'Zacks.com featured highlights Best Buy, AES, Lockheed Martin, PulteGroup and Banco de Chile' is outside the desired time range. Skipping.
# News item 'Top Stock Reports for Toyota, Lockheed Martin & Chubb' is outside the desired time range. Skipping.
# News item 'McDonald's downgraded, PayPal upgraded: Wall Street's top analyst calls' is outside the desired time range. Skipping.
# News item 'Institutional investors have a lot riding on Lockheed Martin Corporation (NYSE:LMT) with 74% ownership' is outside the desired time range. Skipping.
# News item '5 High ROE Stocks to Bet on as Markets Seek Rate Cut Clarity' is outside the desired time range. Skipping.
# News item 'Lockheed Martin Stock: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item '7 Top Defense Stock Picks Geopolitics Continues to Take Center Stage' is outside the desired time range. Skipping.
# News item 'Investors Heavily Search Lockheed Martin Corporation (LMT): Here is What You Need to Know' is outside the desired time range. Skipping.
# News item 'These 3 Companies Posted Robust Quarterly Results' is outside the desired time range. Skipping.
# News item 'HII or LMT: Which Is the Better Value Stock Right Now?' is outside the desired time range. Skipping.
# News item 'PPG launches PPG PRIMERON Optimal powder primer with optimized zinc' is outside the desired time range. Skipping.
# News item 'PPG, Stellantis highlight energy savings from new sealer technology' is outside the desired time range. Skipping.
# News item 'PPG announces partnership with RightShip sustainability platform' is outside the desired time range. Skipping.
# News item 'PPG launches portfolio of energy-curable coatings for coiled metal' is outside the desired time range. Skipping.
# News item 'PPG Industries, Inc. (PPG): Is It Among the Best Dividend Stocks of All Time?' is outside the desired time range. Skipping.
# News item 'PPG recognized for sustainability progress by FTSE4Good for sixth consecutive year' is outside the desired time range. Skipping.
# News item 'PPG extends partnerships with Indianapolis Motor Speedway, INDYCAR, Team Penske' is outside the desired time range. Skipping.
# News item 'PPG Industries' (NYSE:PPG) Shareholders Will Receive A Bigger Dividend Than Last Year' is outside the desired time range. Skipping.
# News item 'Decoding PPG Industries Inc (PPG): A Strategic SWOT Insight' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 2024 Earnings Call Transcript' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings Top Estimates, Sales Lag' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings: How Key Metrics Compare to Wall Street Estimates' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Beats Q2 Earnings Estimates' is outside the desired time range. Skipping.
# News item 'PPG reports second quarter 2024 financial results' is outside the desired time range. Skipping.
# News item 'PPG Board of Directors approves dividend increase to 68 cents per share' is outside the desired time range. Skipping.
# News item 'PPG recognized as ‘Best Place to Work for Disability Inclusion’ for third consecutive year' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) to Post Q2 Earnings: What's in the Cards?' is outside the desired time range. Skipping.
# News item 'Has PPG Industries, Inc. (NYSE:PPG) Stock's Recent Performance Got Anything to Do With Its Financial Health?' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Reports Next Week: Wall Street Expects Earnings Growth' is outside the desired time range. Skipping.
# News item 'Zacks Industry Outlook Highlights PPG Industries, Celanese and Axalta Coating' is outside the desired time range. Skipping.
# News item 'Wall Street Bulls Look Optimistic About Alibaba (BABA): Should You Buy?' is outside the desired time range. Skipping.
# News item 'Japan's SoftBank reduces its investment losses with gains in Alibaba and other holdings' is outside the desired time range. Skipping.
# News item 'Alibaba develops new video generation tool based on Sora's open-source model' is outside the desired time range. Skipping.
# News item 'China approves 487 deepfake algorithms from the likes of Baidu, Alibaba and Tencent' is outside the desired time range. Skipping.
# News item 'Alibaba (BABA) Stock Moves -0.61%: What You Should Know' is outside the desired time range. Skipping.
# News item 'Tencent joins $300m financing round for Chinese AI startup Moonshot' is outside the desired time range. Skipping.
# News item 'Tencent Joins $300 Million Financing for China’s AI Unicorn' is outside the desired time range. Skipping.
# News item 'Alibaba, JD.com, Other Major Overseas Stocks Plunge in Monday Market Selloff' is outside the desired time range. Skipping.
# News item 'Alibaba Group Will Announce June Quarter 2024 Results on August 15, 2024' is outside the desired time range. Skipping.
# News item 'Hong Kong's Futu Launches Bitcoin, Ether Trading, Offers Alibaba, Nvidia Shares as Rewards: Report' is outside the desired time range. Skipping.
# News item 'BABA vs. PDD: Which Chinese E-Commerce Stock Is the Better Buy?' is outside the desired time range. Skipping.
# News item 'China's leading apps, including WeChat and Taobao, test proposed national cyber ID system' is outside the desired time range. Skipping.
# News item 'Online brokerage Futu offers crypto trading in Hong Kong, with Nvidia, Alibaba stock as reward' is outside the desired time range. Skipping.
# News item 'Alibaba To Boost B2B E-Commerce With New AI Sourcing Engine Launch in September' is outside the desired time range. Skipping.
# News item 'Alibaba.com expands by helping former athletes become entrepreneurs' is outside the desired time range. Skipping.
# News item 'Alibaba to deploy AI-powered sourcing engine to boost online trade for global merchants' is outside the desired time range. Skipping.
# News item 'Best Stock to Buy Right Now: JD.com vs. Alibaba' is outside the desired time range. Skipping.
# News item 'Here's Why Alibaba (BABA) Fell More Than Broader Market' is outside the desired time range. Skipping.
# News item 'How to Buy ChatGPT Stocks in 2024' is outside the desired time range. Skipping.
# News item 'Alibaba: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item 'Wayfair Teams Up with Olympic Gold Medal Gymnast Shawn Johnson East in "House to Home" Series' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings Miss Estimates, Revenues Down Y/Y' is outside the desired time range. Skipping.
# News item 'Wayfair CEO flags alarming change in consumer behavior' is outside the desired time range. Skipping.
# News item 'Wayfair CEO Says Furniture Business Similar Now to Great Financial Crisis' is outside the desired time range. Skipping.
# News item 'Investing on interest rate cuts, jobless claims, auto loans: Wealth!' is outside the desired time range. Skipping.
# News item 'Wayfair Sales Fall. Home-Furnishings Decline Is Mirroring the ‘Great Financial Crisis.’' is outside the desired time range. Skipping.
# News item 'What e-commerce earnings may hint about consumer spending' is outside the desired time range. Skipping.
# News item 'Wayfair Quarterly Revenue Unexpectedly Falls Amid 'Unprecedented' Pullback in Consumer Spending' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings: Taking a Look at Key Metrics Versus Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings and Revenues Lag Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair revenue down 1.7% in Q2 as category remains challenged' is outside the desired time range. Skipping.
# News item 'Wayfair (NYSE:W) Misses Q2 Revenue Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair: Q2 Earnings Snapshot' is outside the desired time range. Skipping.
# News item 'Wayfair Announces Second Quarter 2024 Results, Reports Best Quarter of Profitability and Cash Flow in Three Years' is outside the desired time range. Skipping.
# News item 'Want Better Returns? Don't Ignore These 2 Retail-Wholesale Stocks Set to Beat Earnings' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Reports Q2: Everything You Need To Know Ahead Of Earnings' is outside the desired time range. Skipping.
# News item 'Analysts Estimate Coupang, Inc. (CPNG) to Report a Decline in Earnings: What to Look Out for' is outside the desired time range. Skipping.
# News item 'Countdown to Wayfair (W) Q2 Earnings: A Look at Estimates Beyond Revenue and EPS' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Earnings Expected to Grow: Should You Buy?' is outside the desired time range. Skipping.
# News item 'Why Investors Need to Take Advantage of These 2 Retail-Wholesale Stocks Now' is outside the desired time range. Skipping.
# News item 'R1 RCM INC (RCM) Reports Q2 Earnings: What Key Metrics Have to Say' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc. (RCM) Reports Q2 Loss, Lags Revenue Estimates' is outside the desired time range. Skipping.
# News item 'R1 RCM Reports Second Quarter 2024 Results' is outside the desired time range. Skipping.
# News item 'Revenue cycle management firm R1 RCM to go private in $8.9B acquisition' is outside the desired time range. Skipping.
# News item 'Market Chatter: RBC, Deutsche Bank Plan US$4.5 Billion Debt Sale for R1 RCM buyout' is outside the desired time range. Skipping.
# News item 'Investment funds to take healthcare tech company R1 RCM private in nearly $9B deal' is outside the desired time range. Skipping.
# News item 'R1 to Go Private in $8.9 Billion Deal with TowerBrook, CD&R' is outside the desired time range. Skipping.
# News item 'R1 RCM to be Acquired by TowerBrook and CD&R for $8.9 Billion' is outside the desired time range. Skipping.
# News item 'R1 RCM Special Committee Provides Update on Evaluation of Strategic Alternatives' is outside the desired time range. Skipping.
# News item 'TowerBrook, CD&R in Advanced Talks to Make Offer for Health IT Firm R1 RCM' is outside the desired time range. Skipping.
# News item 'TowerBrook, CD&R Consider Joining Forces to Bid for R1 RCM' is outside the desired time range. Skipping.
# News item 'Merger-Arb Traders Bet on a Few Deals After Ugly Start of Year' is outside the desired time range. Skipping.
# News item 'R1 RCM to Release Second Quarter 2024 Results on August 7, 2024' is outside the desired time range. Skipping.
# News item 'New Mountain offers to acquire healthcare services provider R1 RCM' is outside the desired time range. Skipping.
# News item 'Stocks to Watch Tuesday: Tesla, Chewy, Nvidia' is outside the desired time range. Skipping.
# News item 'R1 RCM to Host a Virtual Event “Technology Teach-In: A Deep Dive into Key Focus Areas and the R1 Platform” on June 27, 2024' is outside the desired time range. Skipping.
# News item 'R1 RCM to Present at the 2024 Jefferies Global Healthcare Conference' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc. (NASDAQ:RCM) Q1 2024 Earnings Call Transcript' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc (RCM) Q1 2024 Earnings Call Transcript Highlights: Navigating Challenges with Robust ...' is outside the desired time range. Skipping.
# News item 'Compared to Estimates, R1 RCM INC (RCM) Q1 Earnings: A Look at Key Metrics' is outside the desired time range. Skipping.
# News item 'LPH initiates sale process for Wingstop business in UK' is outside the desired time range. Skipping.
# News item 'Stocks eye the day's tech earnings, Etsy CEO: Market Domination' is outside the desired time range. Skipping.
# News item 'Wingstop is in 'a category of one': CEO talks expansion' is outside the desired time range. Skipping.
# News item 'WWE's SummerSlam to be filled with action - and lots of sponsors' is outside the desired time range. Skipping.
# News item 'Wingstop Second Quarter 2024 Earnings: Beats Expectations' is outside the desired time range. Skipping.
# News item 'Wingstop reports 70% jump in Q2 2024 net income' is outside the desired time range. Skipping.
# News item 'Wingstop cracks $2M AUV in another record-breaking quarter' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Q2 Earnings: How Key Metrics Compare to Wall Street Estimates' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Beats Q2 Earnings and Revenue Estimates' is outside the desired time range. Skipping.
# News item 'Wingstop (NASDAQ:WING) Beats Expectations in Strong Q2' is outside the desired time range. Skipping.
# News item 'Wingstop: Q2 Earnings Snapshot' is outside the desired time range. Skipping.
# News item 'Wingstop Inc. Reports Fiscal Second Quarter 2024 Financial Results' is outside the desired time range. Skipping.
# News item 'Are Retail-Wholesale Stocks Lagging  Urban Outfitters (URBN) This Year?' is outside the desired time range. Skipping.
# News item '6 Restaurant Stocks Eat McDonald's Lunch' is outside the desired time range. Skipping.
# News item '3 Restaurant Stocks to Buy and Hold for Great Long-Term Potential' is outside the desired time range. Skipping.
# News item 'Polen Capital U.S. SMID Company Growth Strategy Sold Wingstop (WING) After Share Price Appreciation' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Reports Earnings Tomorrow: What To Expect' is outside the desired time range. Skipping.
# News item 'Artisan Small Cap Fund Trimmed Wingstop (WING) on Valuation Discipline' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) to Post Q2 Earnings: What's in the Offing?' is outside the desired time range. Skipping.
# News item 'Seeking Clues to Wingstop (WING) Q2 Earnings? A Peek Into Wall Street Projections for Key Metrics' is outside the desired time range. Skipping.
# News item 'Uber's Latest Results May Help 'Subdue' Consumer Slowdown Concerns, BofA Securities Says' is outside the desired time range. Skipping.
# News item 'Instacart and Uber Are Booming. Why Gig Economy Stocks Could Be Recession-Proof.' is outside the desired time range. Skipping.
# News item 'Stock Market News for Aug 7, 2024' is outside the desired time range. Skipping.
# News item 'Lyft Shares Tank After Bookings and Outlook Miss Estimates' is outside the desired time range. Skipping.
# News item 'Lyft Q2 Earnings: Active Riders Increase 10%, Gross Bookings Surge 17%, Introduces Price Lock Feature' is outside the desired time range. Skipping.
# News item 'How Should You Play UBER Stock Following Q2 Earnings Beat?' is outside the desired time range. Skipping.
# News item 'ETFs to Buy as Uber Rallies Post Earnings Release' is outside the desired time range. Skipping.
# News item 'With 82% ownership, Uber Technologies, Inc. (NYSE:UBER) boasts of strong institutional backing' is outside the desired time range. Skipping.
# News item 'Q2 2024 Uber Technologies Inc Earnings Call' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'S&P 500 Gains and Losses Today: Kenvue Soars on Band-Aid Maker's Strong Outlook' is outside the desired time range. Skipping.
# News item 'Why Is Uber Technologies, Inc. (UBER) the Best Travel and Leisure Stock to Buy According to Hedge Funds?' is outside the desired time range. Skipping.
# News item 'Uber Shares Jump as Company Returns to Profitability' is outside the desired time range. Skipping.
# News item 'Uber Stock Jumps As Earnings Return, Sales Growth Picks Up' is outside the desired time range. Skipping.
# News item 'Big Tech stocks: It's time to go bargain hunting, analyst says' is outside the desired time range. Skipping.
# News item 'Uber Freight EBITDA still in the red, and revenue continues to slide' is outside the desired time range. Skipping.
# News item 'How to navigate market volatility, buying a home: Wealth!' is outside the desired time range. Skipping.
# News item 'Stock movers: Nvidia rebounds; Uber, Palantir, Caterpillar up' is outside the desired time range. Skipping.
# News item 'UBER Q2 Earnings & Revenues Surpass Estimates, Up Y/Y' is outside the desired time range. Skipping.
# News item 'Top Stock Movers Now: Kenvue, Uber, Palantir, and More' is outside the desired time range. Skipping.
# No new news found at 2024-08-07 12:58:18 EDT
# Fetching data at 2024-08-07 12:59:21 EDT
# Fetching news for tickers: ['AAPL', 'AMZN', 'MSFT', 'BYND', 'TSLA', 'GOOGL', 'GOOG', 'NVDA', 'LMT', 'PPG', 'BABA', 'W', 'RCM', 'WING', 'UBER']
# News item 'Why you may want to wait to buy a new iPhone' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'Apple could lose $20bn in Google search antitrust ruling' is outside the desired time range. Skipping.
# News item 'Best Stock to Buy Right Now: Amazon vs. Apple' is outside the desired time range. Skipping.
# News item 'Jim Cramer: Market Will Never Give Apple Inc (AAPL) ‘Benefit of the Doubt’' is outside the desired time range. Skipping.
# News item 'The Zacks Analyst Blog SPY, Apple and Micron Technology' is outside the desired time range. Skipping.
# News item 'Warren Buffett Just Sold $90 Billion of Apple Stock. Could This Be the Biggest Investing Mistake He's Ever Made?' is outside the desired time range. Skipping.
# News item 'Nasdaq Market Correction: 1 "Magnificent Seven" Stock to Buy Now, and Another to Avoid' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'Google’s unlawful grip on search could shatter its market dominance' is outside the desired time range. Skipping.
# News item 'A judge has branded Google a monopolist, but AI may bring about quicker change in internet search' is outside the desired time range. Skipping.
# News item 'Google Has Been Ruled a Monopoly. On the Internet, It May Not Matter.' is outside the desired time range. Skipping.
# News item 'A Microsoft victory and Mozilla defeat: The fallout from Google’s antitrust saga' is outside the desired time range. Skipping.
# News item 'Apple Intelligence's writing tools stumble on swears and controversial topics' is outside the desired time range. Skipping.
# News item 'Made by Google 2024: Pixel 9, Gemini, a new foldable and other things to expect from the event' is outside the desired time range. Skipping.
# News item 'These Stocks Moved the Most Today: Palantir, Nvidia, Uber, Caterpillar, CrowdStrike, Lumen, Kenvue, ZoomInfo, and More' is outside the desired time range. Skipping.
# News item 'Big Tech stocks: It's time to go bargain hunting, analyst says' is outside the desired time range. Skipping.
# News item 'Google antitrust ruling may pose $20 billion risk for Apple' is outside the desired time range. Skipping.
# News item '2 Top S&P 500 Stocks to Buy on Market Dip: AAPL, MU' is outside the desired time range. Skipping.
# News item 'Analysts review Apple stock price hit from Google antitrust ruling' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item '"Rule Breaker Investing" Great Quotes, Vol. 19: Authors in August' is outside the desired time range. Skipping.
# News item 'Where Will Nvidia Stock Be in 5 Years?' is outside the desired time range. Skipping.
# News item 'Why This 1 Growth Stock Could Be a Great Addition to Your Portfolio' is outside the desired time range. Skipping.
# News item 'Rivian Stock Drops, but the Electric Vehicle (EV) Maker Remains on Track to Achieve a Gross Profit in Q4' is outside the desired time range. Skipping.
# News item 'Jeff Bezos Once Said 'Life's Too Short To Hang Out With People Who Aren't Resourceful' — Who Are The People That Helped The Amazon Founder Take Steps Toward Success' is outside the desired time range. Skipping.
# News item 'Cathie Wood Goes Bargain Hunting in the Market Sell-Off: 2 Top Stocks She Just Bought' is outside the desired time range. Skipping.
# News item 'Best Stock to Buy Right Now: Amazon vs. Apple' is outside the desired time range. Skipping.
# News item 'Amazon Prime Video plots Hollywood expansion' is outside the desired time range. Skipping.
# News item '3 ways to play AI after sell-off: Strategist explains' is outside the desired time range. Skipping.
# News item 'Stock Market Sell-Off: 2 Top Stocks I Plan to Buy if the Market Keeps Melting Down' is outside the desired time range. Skipping.
# News item 'Jim Cramer: Amazon.com Inc (NASDAQ:AMZN) Results Were ‘Imperfect’' is outside the desired time range. Skipping.
# News item 'The Ultimate Growth Stock to Buy With $1,000 Right Now' is outside the desired time range. Skipping.
# News item 'Yes, I'd Buy Amazon Stock on This Post-Earnings Dip. Here's Why' is outside the desired time range. Skipping.
# News item 'Nasdaq Market Correction: 1 "Magnificent Seven" Stock to Buy Now, and Another to Avoid' is outside the desired time range. Skipping.
# News item 'Why Meta Platforms Stock Was Gaining on Tuesday' is outside the desired time range. Skipping.
# News item 'Q2 2024 Celsius Holdings Inc Earnings Call' is outside the desired time range. Skipping.
# News item 'Analysts rethink Amazon stock price targets after earnings' is outside the desired time range. Skipping.
# News item 'Cathie Wood buys $28 million of battered tech stock' is outside the desired time range. Skipping.
# News item 'Time to Buy the Recent Dip in Microsoft or Amazon's Stock?' is outside the desired time range. Skipping.
# News item 'Q2 2024 Qualys Inc Earnings Call' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'Microsoft links security protocols to employee promotion, according to internal memo' is outside the desired time range. Skipping.
# News item 'Microsoft Slams Delta CrowdStrike Tech-Outage Claims as ‘False’' is outside the desired time range. Skipping.
# News item 'Datadog and Landstar System have been highlighted as Zacks Bull and Bear of the Day' is outside the desired time range. Skipping.
# News item 'Prediction: This Will Be One of the World's First $5 Trillion Artificial Intelligence (AI) Stocks' is outside the desired time range. Skipping.
# News item 'Better AI Stock: Lumen Technologies vs. Broadcom' is outside the desired time range. Skipping.
# News item 'Microsoft hits back at Delta after the airline said last month's tech outage cost it $500 million' is outside the desired time range. Skipping.
# News item 'Why CrowdStrike Stock Finished Higher Today' is outside the desired time range. Skipping.
# News item 'Time to Buy the Recent Dip in Microsoft or Amazon's Stock?' is outside the desired time range. Skipping.
# News item 'Stocks rebound, Reddit posts Q2 earnings: Asking for a Trend' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'Why tech's AI spending boom may not be what you think: Analyst' is outside the desired time range. Skipping.
# News item 'A judge has branded Google a monopolist, but AI may bring about quicker change in internet search' is outside the desired time range. Skipping.
# News item 'Google Has Been Ruled a Monopoly. On the Internet, It May Not Matter.' is outside the desired time range. Skipping.
# News item 'A Microsoft victory and Mozilla defeat: The fallout from Google’s antitrust saga' is outside the desired time range. Skipping.
# News item 'Microsoft Joins CrowdStrike in Criticizing Delta's Response to Outage' is outside the desired time range. Skipping.
# News item 'Microsoft lashes out at Delta: Your ancient tech caused the service meltdown' is outside the desired time range. Skipping.
# News item 'Google just lost a big antitrust trial. Now it has to face another.' is outside the desired time range. Skipping.
# News item 'Magnificent Seven Stocks: Nvidia Stock Rebounds; Apple Slides' is outside the desired time range. Skipping.
# News item 'Beyond Meat (BYND) To Report Earnings Tomorrow: Here Is What To Expect' is outside the desired time range. Skipping.
# News item 'These Are The Five Best Stocks To Buy And Watch Now' is outside the desired time range. Skipping.
# News item 'Short-Seller Left’s Deleted Tweets Reappear in Fraud Case' is outside the desired time range. Skipping.
# News item 'Beyond Meat, Inc. (NASDAQ:BYND) is definitely on the radar of institutional investors who own 48% of the company' is outside the desired time range. Skipping.
# News item '7 Must-Sell Stocks Before the Mother of All Bear Markets' is outside the desired time range. Skipping.
# News item 'The 3 Best Plant-Based Meat Stocks to Buy Now: July 2024' is outside the desired time range. Skipping.
# News item 'Reflecting On Perishable Food Stocks’ Q1 Earnings: Beyond Meat (NASDAQ:BYND)' is outside the desired time range. Skipping.
# News item 'Beyond Meat® to Report Second Quarter 2024 Financial Results on August 7, 2024' is outside the desired time range. Skipping.
# News item 'Beyond Meat rolls out a new product not intended to replicate beef, pork, or poultry' is outside the desired time range. Skipping.
# News item 'Beyond Meat Debuts New Product Innovation, Beyond Sun Sausage™, Exclusively at Sprouts Farmers Market Stores Nationwide' is outside the desired time range. Skipping.
# News item '7 Meme Mania Stocks: Which Are FOMO and Which Are Free Money?' is outside the desired time range. Skipping.
# News item 'Beyond Meat launches ‘first of its kind’ protein to appeal to health-conscious consumers' is outside the desired time range. Skipping.
# News item 'Chicago Fed Pres. speaks on inflation goal, ECB issues warning: Catalysts' is outside the desired time range. Skipping.
# News item 'Is Beyond Meat (BYND) Stock on the Brink of Death?' is outside the desired time range. Skipping.
# News item 'Why Beyond Meat Is Crashing Today' is outside the desired time range. Skipping.
# News item 'Stocks to Watch Thursday: Netflix, Abbott Laboratories, Domino's Pizza, Warner Bros.' is outside the desired time range. Skipping.
# News item 'Beyond Meat sinks on restructuring talks with bondholders' is outside the desired time range. Skipping.
# News item 'Why Beyond Meat (BYND) Stock Is Nosediving' is outside the desired time range. Skipping.
# News item 'Beyond Meat Slides. Balance-Sheet Talks Are Burning the Stock.' is outside the desired time range. Skipping.
# News item 'Midday movers: DR Horton, Kinder Morgan rise ; Domino's Pizza, Beyond Meat fall' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'Tesla Stock Is Falling. Uber’s Self-Driving News Didn’t Help.' is outside the desired time range. Skipping.
# News item 'Tesla Stock Ended Higher. It Was All About Japan.' is outside the desired time range. Skipping.
# News item 'Sunrun Stock Surges After Surprise Profit. The Solar Panel Installer Teams Up With Tesla.' is outside the desired time range. Skipping.
# News item 'Why this Tesla investor and Elon Musk supporter is buying the stock dip' is outside the desired time range. Skipping.
# News item 'A black swan market crash on the horizon?' is outside the desired time range. Skipping.
# News item 'Elon Musk’s backing of Donald Trump is hurting Tesla’s struggling EV business in Europe' is outside the desired time range. Skipping.
# News item 'This "Magnificent Seven" Stock Has Tanked 7% in 2024: Is It Time to Buy the Dip?' is outside the desired time range. Skipping.
# News item 'Jim Cramer Says You Can Buy Tesla Inc (NASDAQ:TSLA) ‘Right Here’' is outside the desired time range. Skipping.
# News item 'Americans just can’t quit their giant, gas-burning trucks' is outside the desired time range. Skipping.
# News item 'Tesla Deploys Fix to 1.6 Million Cars in China for Hood Lock' is outside the desired time range. Skipping.
# News item 'Tesla Recalling 1.68 Million Cars in China Over Hood Problem' is outside the desired time range. Skipping.
# News item 'Tesla is recalling more than 1.6 million cars in China for a remote software fix' is outside the desired time range. Skipping.
# News item 'EV Fund Outflows Hit $1.6 Billion as Trump Fears Add to Slowdown' is outside the desired time range. Skipping.
# News item 'Sunrun and Tesla Partner to Support Texas Power Grid Using Residential Solar-Plus-Battery Systems' is outside the desired time range. Skipping.
# News item 'Every Time We Drive We Wonder If Is It Going To Break Again,' Says A Cybertruck Owner Prompting Elon Musk To Step In Personally' is outside the desired time range. Skipping.
# News item 'Magnificent Seven Stocks: Nvidia Stock Rebounds; Apple Slides' is outside the desired time range. Skipping.
# News item 'German drugstore chain shuns Teslas over Musk's support for Trump' is outside the desired time range. Skipping.
# News item 'Stock market turmoil ‘only half complete’, warns Wall Street giant' is outside the desired time range. Skipping.
# News item 'Top Stock Reports for Berkshire Hathaway, Tesla & Visa' is outside the desired time range. Skipping.
# News item 'Where Will Duolingo Be in 5 Years?' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'We Like Alphabet's (NASDAQ:GOOGL) Returns And Here's How They're Trending' is outside the desired time range. Skipping.
# News item 'Meet Vanguard's 3 Hottest Sector ETFs in 2024 (and None of Them Are Tech)' is outside the desired time range. Skipping.
# News item 'Waymo expands in California' is outside the desired time range. Skipping.
# News item 'Apple could lose $20bn in Google search antitrust ruling' is outside the desired time range. Skipping.
# News item 'Hyundai exploring partnership with Google for connected car tech' is outside the desired time range. Skipping.
# News item '1 No-Brainer Artificial Intelligence (AI) Stock to Buy Following the Nasdaq's Recent Drop' is outside the desired time range. Skipping.
# News item '1 Stock-Split Artificial Intelligence (AI) Stock to Buy Before It Skyrockets 67%, According to One Wall Street Analyst' is outside the desired time range. Skipping.
# News item 'This Undervalued Stock Could Join Alphabet in the $2 Trillion Club' is outside the desired time range. Skipping.
# News item 'Why Meta Platforms Stock Was Gaining on Tuesday' is outside the desired time range. Skipping.
# News item 'The AI founder exodus' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'Google’s unlawful grip on search could shatter its market dominance' is outside the desired time range. Skipping.
# News item 'A judge has branded Google a monopolist, but AI may bring about quicker change in internet search' is outside the desired time range. Skipping.
# News item 'Google Has Been Ruled a Monopoly. On the Internet, It May Not Matter.' is outside the desired time range. Skipping.
# News item 'Google Assistant lives to automate another day' is outside the desired time range. Skipping.
# News item 'A Microsoft victory and Mozilla defeat: The fallout from Google’s antitrust saga' is outside the desired time range. Skipping.
# News item 'Google Says It Will Appeal Antitrust Ruling—What That Could Mean for Big Tech' is outside the desired time range. Skipping.
# News item 'Made by Google 2024: Pixel 9, Gemini, a new foldable and other things to expect from the event' is outside the desired time range. Skipping.
# News item 'Where Will Duolingo Be in 5 Years?' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'We Like Alphabet's (NASDAQ:GOOGL) Returns And Here's How They're Trending' is outside the desired time range. Skipping.
# News item 'Meet Vanguard's 3 Hottest Sector ETFs in 2024 (and None of Them Are Tech)' is outside the desired time range. Skipping.
# News item 'Waymo expands in California' is outside the desired time range. Skipping.
# News item 'Apple could lose $20bn in Google search antitrust ruling' is outside the desired time range. Skipping.
# News item 'Hyundai exploring partnership with Google for connected car tech' is outside the desired time range. Skipping.
# News item '1 No-Brainer Artificial Intelligence (AI) Stock to Buy Following the Nasdaq's Recent Drop' is outside the desired time range. Skipping.
# News item '1 Stock-Split Artificial Intelligence (AI) Stock to Buy Before It Skyrockets 67%, According to One Wall Street Analyst' is outside the desired time range. Skipping.
# News item 'This Undervalued Stock Could Join Alphabet in the $2 Trillion Club' is outside the desired time range. Skipping.
# News item 'Why Meta Platforms Stock Was Gaining on Tuesday' is outside the desired time range. Skipping.
# News item 'The AI founder exodus' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'Google’s unlawful grip on search could shatter its market dominance' is outside the desired time range. Skipping.
# News item 'A judge has branded Google a monopolist, but AI may bring about quicker change in internet search' is outside the desired time range. Skipping.
# News item 'Google Has Been Ruled a Monopoly. On the Internet, It May Not Matter.' is outside the desired time range. Skipping.
# News item 'Google Assistant lives to automate another day' is outside the desired time range. Skipping.
# News item 'A Microsoft victory and Mozilla defeat: The fallout from Google’s antitrust saga' is outside the desired time range. Skipping.
# News item 'Google Says It Will Appeal Antitrust Ruling—What That Could Mean for Big Tech' is outside the desired time range. Skipping.
# News item 'Made by Google 2024: Pixel 9, Gemini, a new foldable and other things to expect from the event' is outside the desired time range. Skipping.
# News item 'Traders Brace for More S&P 500 Volatility After Jobless Claims' is outside the desired time range. Skipping.
# News item 'Super Micro Computer Stock Tumbles as Soaring Revenue Misses Expectations' is outside the desired time range. Skipping.
# News item 'Dow Jones, Nasdaq Off The Day's Highs; Cybersecurity Stock Soars (Live Coverage)' is outside the desired time range. Skipping.
# News item 'Big Tech is in 'penalty box' for now: Barclays strategist' is outside the desired time range. Skipping.
# News item 'Nvidia Rises Amid Strong 'Hyperscaler' Demand, But Is It A Buy Now?' is outside the desired time range. Skipping.
# News item '"Rule Breaker Investing" Great Quotes, Vol. 19: Authors in August' is outside the desired time range. Skipping.
# News item 'Here's My Top AI Stock to Buy in August' is outside the desired time range. Skipping.
# News item 'Nvidia, chip stocks rebound as Piper Sandler calls out 'tremendous opportunity' after sell-off' is outside the desired time range. Skipping.
# News item 'Nvidia Stock Rising Again. How Super Micro Allayed AI Chip Fears.' is outside the desired time range. Skipping.
# News item 'Oracle: Overvalued Despite AI Driving Fundamental Growth' is outside the desired time range. Skipping.
# News item 'Where Will Nvidia Stock Be in 5 Years?' is outside the desired time range. Skipping.
# News item 'AMD Stock Is a Buy Thanks to This Improving Metric' is outside the desired time range. Skipping.
# News item ''Magnificent Seven' rebounds, Nvidia leads the charge' is outside the desired time range. Skipping.
# News item 'Dow Jones Rallies 300 Points; Nvidia Partner Super Micro Plunges On Earnings (Live Coverage)' is outside the desired time range. Skipping.
# News item 'AI Stocks: Tech Giants, Cloud Titans Face 'Show Me' Moment' is outside the desired time range. Skipping.
# News item 'SoftBank’s Latest Big Purchase Could Be One of Its Best' is outside the desired time range. Skipping.
# News item 'Is It Too Late to Buy Dell Stock?' is outside the desired time range. Skipping.
# News item 'Dow Jones Futures Fuel New Market Rally On Bank Of Japan; Nvidia Partner Super Micro Dives' is outside the desired time range. Skipping.
# News item 'Successful Follow-Throughs Signal Market Bottoms, Offer Breakouts' is outside the desired time range. Skipping.
# News item 'Where Will Nvidia Stock Be in 1 Year?' is outside the desired time range. Skipping.
# News item 'What's in Store for Virgin Galactic (SPCE) in Q2 Earnings?' is outside the desired time range. Skipping.
# News item 'Lockheed Martin Insiders Sell US$13m Of Stock, Possibly Signalling Caution' is outside the desired time range. Skipping.
# News item 'Crypto sell-off, services PMI data, tech trends: Catalysts' is outside the desired time range. Skipping.
# News item 'Lockheed Martin's Sales Outlook Has Improved Investor Sentiment, RBC Says' is outside the desired time range. Skipping.
# News item 'Tyson Foods, Lockheed Martin, Kellanova: 3 stocks in focus' is outside the desired time range. Skipping.
# News item 'Lockheed Stock Is Up. Defense Is the Best Defense in an AI Stock Crunch.' is outside the desired time range. Skipping.
# News item 'Aerospace & Defense ETFs to Track Amid Q2 Earnings' is outside the desired time range. Skipping.
# News item 'Why Northrop Grumman Stock Shot Higher in July' is outside the desired time range. Skipping.
# News item 'Are Aerospace Stocks Lagging  Leidos (LDOS) This Year?' is outside the desired time range. Skipping.
# News item 'The Zacks Analyst Blog Highlights Toyota Motor, Lockheed Martin, Chubb and Pro-Dex' is outside the desired time range. Skipping.
# News item 'Zacks.com featured highlights Best Buy, AES, Lockheed Martin, PulteGroup and Banco de Chile' is outside the desired time range. Skipping.
# News item 'Top Stock Reports for Toyota, Lockheed Martin & Chubb' is outside the desired time range. Skipping.
# News item 'McDonald's downgraded, PayPal upgraded: Wall Street's top analyst calls' is outside the desired time range. Skipping.
# News item 'Institutional investors have a lot riding on Lockheed Martin Corporation (NYSE:LMT) with 74% ownership' is outside the desired time range. Skipping.
# News item '5 High ROE Stocks to Bet on as Markets Seek Rate Cut Clarity' is outside the desired time range. Skipping.
# News item 'Lockheed Martin Stock: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item '7 Top Defense Stock Picks Geopolitics Continues to Take Center Stage' is outside the desired time range. Skipping.
# News item 'Investors Heavily Search Lockheed Martin Corporation (LMT): Here is What You Need to Know' is outside the desired time range. Skipping.
# News item 'These 3 Companies Posted Robust Quarterly Results' is outside the desired time range. Skipping.
# News item 'HII or LMT: Which Is the Better Value Stock Right Now?' is outside the desired time range. Skipping.
# News item 'PPG launches PPG PRIMERON Optimal powder primer with optimized zinc' is outside the desired time range. Skipping.
# News item 'PPG, Stellantis highlight energy savings from new sealer technology' is outside the desired time range. Skipping.
# News item 'PPG announces partnership with RightShip sustainability platform' is outside the desired time range. Skipping.
# News item 'PPG launches portfolio of energy-curable coatings for coiled metal' is outside the desired time range. Skipping.
# News item 'PPG Industries, Inc. (PPG): Is It Among the Best Dividend Stocks of All Time?' is outside the desired time range. Skipping.
# News item 'PPG recognized for sustainability progress by FTSE4Good for sixth consecutive year' is outside the desired time range. Skipping.
# News item 'PPG extends partnerships with Indianapolis Motor Speedway, INDYCAR, Team Penske' is outside the desired time range. Skipping.
# News item 'PPG Industries' (NYSE:PPG) Shareholders Will Receive A Bigger Dividend Than Last Year' is outside the desired time range. Skipping.
# News item 'Decoding PPG Industries Inc (PPG): A Strategic SWOT Insight' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 2024 Earnings Call Transcript' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings Top Estimates, Sales Lag' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings: How Key Metrics Compare to Wall Street Estimates' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Beats Q2 Earnings Estimates' is outside the desired time range. Skipping.
# News item 'PPG reports second quarter 2024 financial results' is outside the desired time range. Skipping.
# News item 'PPG Board of Directors approves dividend increase to 68 cents per share' is outside the desired time range. Skipping.
# News item 'PPG recognized as ‘Best Place to Work for Disability Inclusion’ for third consecutive year' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) to Post Q2 Earnings: What's in the Cards?' is outside the desired time range. Skipping.
# News item 'Has PPG Industries, Inc. (NYSE:PPG) Stock's Recent Performance Got Anything to Do With Its Financial Health?' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Reports Next Week: Wall Street Expects Earnings Growth' is outside the desired time range. Skipping.
# News item 'Zacks Industry Outlook Highlights PPG Industries, Celanese and Axalta Coating' is outside the desired time range. Skipping.
# News item 'Wall Street Bulls Look Optimistic About Alibaba (BABA): Should You Buy?' is outside the desired time range. Skipping.
# News item 'Japan's SoftBank reduces its investment losses with gains in Alibaba and other holdings' is outside the desired time range. Skipping.
# News item 'Alibaba develops new video generation tool based on Sora's open-source model' is outside the desired time range. Skipping.
# News item 'China approves 487 deepfake algorithms from the likes of Baidu, Alibaba and Tencent' is outside the desired time range. Skipping.
# News item 'Alibaba (BABA) Stock Moves -0.61%: What You Should Know' is outside the desired time range. Skipping.
# News item 'Tencent joins $300m financing round for Chinese AI startup Moonshot' is outside the desired time range. Skipping.
# News item 'Tencent Joins $300 Million Financing for China’s AI Unicorn' is outside the desired time range. Skipping.
# News item 'Alibaba, JD.com, Other Major Overseas Stocks Plunge in Monday Market Selloff' is outside the desired time range. Skipping.
# News item 'Alibaba Group Will Announce June Quarter 2024 Results on August 15, 2024' is outside the desired time range. Skipping.
# News item 'Hong Kong's Futu Launches Bitcoin, Ether Trading, Offers Alibaba, Nvidia Shares as Rewards: Report' is outside the desired time range. Skipping.
# News item 'BABA vs. PDD: Which Chinese E-Commerce Stock Is the Better Buy?' is outside the desired time range. Skipping.
# News item 'China's leading apps, including WeChat and Taobao, test proposed national cyber ID system' is outside the desired time range. Skipping.
# News item 'Online brokerage Futu offers crypto trading in Hong Kong, with Nvidia, Alibaba stock as reward' is outside the desired time range. Skipping.
# News item 'Alibaba To Boost B2B E-Commerce With New AI Sourcing Engine Launch in September' is outside the desired time range. Skipping.
# News item 'Alibaba.com expands by helping former athletes become entrepreneurs' is outside the desired time range. Skipping.
# News item 'Alibaba to deploy AI-powered sourcing engine to boost online trade for global merchants' is outside the desired time range. Skipping.
# News item 'Best Stock to Buy Right Now: JD.com vs. Alibaba' is outside the desired time range. Skipping.
# News item 'Here's Why Alibaba (BABA) Fell More Than Broader Market' is outside the desired time range. Skipping.
# News item 'How to Buy ChatGPT Stocks in 2024' is outside the desired time range. Skipping.
# News item 'Alibaba: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item 'Wayfair Teams Up with Olympic Gold Medal Gymnast Shawn Johnson East in "House to Home" Series' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings Miss Estimates, Revenues Down Y/Y' is outside the desired time range. Skipping.
# News item 'Wayfair CEO flags alarming change in consumer behavior' is outside the desired time range. Skipping.
# News item 'Wayfair CEO Says Furniture Business Similar Now to Great Financial Crisis' is outside the desired time range. Skipping.
# News item 'Investing on interest rate cuts, jobless claims, auto loans: Wealth!' is outside the desired time range. Skipping.
# News item 'Wayfair Sales Fall. Home-Furnishings Decline Is Mirroring the ‘Great Financial Crisis.’' is outside the desired time range. Skipping.
# News item 'What e-commerce earnings may hint about consumer spending' is outside the desired time range. Skipping.
# ...
# News item '5 High ROE Stocks to Bet on as Markets Seek Rate Cut Clarity' is outside the desired time range. Skipping.
# News item 'Lockheed Martin Stock: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item '7 Top Defense Stock Picks Geopolitics Continues to Take Center Stage' is outside the desired time range. Skipping.
# News item 'Investors Heavily Search Lockheed Martin Corporation (LMT): Here is What You Need to Know' is outside the desired time range. Skipping.
# News item 'These 3 Companies Posted Robust Quarterly Results' is outside the desired time range. Skipping.
# News item 'HII or LMT: Which Is the Better Value Stock Right Now?' is outside the desired time range. Skipping.
# News item 'PPG launches PPG PRIMERON Optimal powder primer with optimized zinc' is outside the desired time range. Skipping.
# News item 'PPG, Stellantis highlight energy savings from new sealer technology' is outside the desired time range. Skipping.
# News item 'PPG announces partnership with RightShip sustainability platform' is outside the desired time range. Skipping.
# News item 'PPG launches portfolio of energy-curable coatings for coiled metal' is outside the desired time range. Skipping.
# News item 'PPG Industries, Inc. (PPG): Is It Among the Best Dividend Stocks of All Time?' is outside the desired time range. Skipping.
# News item 'PPG recognized for sustainability progress by FTSE4Good for sixth consecutive year' is outside the desired time range. Skipping.
# News item 'PPG extends partnerships with Indianapolis Motor Speedway, INDYCAR, Team Penske' is outside the desired time range. Skipping.
# News item 'PPG Industries' (NYSE:PPG) Shareholders Will Receive A Bigger Dividend Than Last Year' is outside the desired time range. Skipping.
# News item 'Decoding PPG Industries Inc (PPG): A Strategic SWOT Insight' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 2024 Earnings Call Transcript' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings Top Estimates, Sales Lag' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Q2 Earnings: How Key Metrics Compare to Wall Street Estimates' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Beats Q2 Earnings Estimates' is outside the desired time range. Skipping.
# News item 'PPG reports second quarter 2024 financial results' is outside the desired time range. Skipping.
# News item 'PPG Board of Directors approves dividend increase to 68 cents per share' is outside the desired time range. Skipping.
# News item 'PPG recognized as ‘Best Place to Work for Disability Inclusion’ for third consecutive year' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) to Post Q2 Earnings: What's in the Cards?' is outside the desired time range. Skipping.
# News item 'Has PPG Industries, Inc. (NYSE:PPG) Stock's Recent Performance Got Anything to Do With Its Financial Health?' is outside the desired time range. Skipping.
# News item 'PPG Industries (PPG) Reports Next Week: Wall Street Expects Earnings Growth' is outside the desired time range. Skipping.
# News item 'Zacks Industry Outlook Highlights PPG Industries, Celanese and Axalta Coating' is outside the desired time range. Skipping.
# News item 'Wall Street Bulls Look Optimistic About Alibaba (BABA): Should You Buy?' is outside the desired time range. Skipping.
# News item 'Japan's SoftBank reduces its investment losses with gains in Alibaba and other holdings' is outside the desired time range. Skipping.
# News item 'Alibaba develops new video generation tool based on Sora's open-source model' is outside the desired time range. Skipping.
# News item 'China approves 487 deepfake algorithms from the likes of Baidu, Alibaba and Tencent' is outside the desired time range. Skipping.
# News item 'Alibaba (BABA) Stock Moves -0.61%: What You Should Know' is outside the desired time range. Skipping.
# News item 'Tencent joins $300m financing round for Chinese AI startup Moonshot' is outside the desired time range. Skipping.
# News item 'Tencent Joins $300 Million Financing for China’s AI Unicorn' is outside the desired time range. Skipping.
# News item 'Alibaba, JD.com, Other Major Overseas Stocks Plunge in Monday Market Selloff' is outside the desired time range. Skipping.
# News item 'Alibaba Group Will Announce June Quarter 2024 Results on August 15, 2024' is outside the desired time range. Skipping.
# News item 'Hong Kong's Futu Launches Bitcoin, Ether Trading, Offers Alibaba, Nvidia Shares as Rewards: Report' is outside the desired time range. Skipping.
# News item 'BABA vs. PDD: Which Chinese E-Commerce Stock Is the Better Buy?' is outside the desired time range. Skipping.
# News item 'China's leading apps, including WeChat and Taobao, test proposed national cyber ID system' is outside the desired time range. Skipping.
# News item 'Online brokerage Futu offers crypto trading in Hong Kong, with Nvidia, Alibaba stock as reward' is outside the desired time range. Skipping.
# News item 'Alibaba To Boost B2B E-Commerce With New AI Sourcing Engine Launch in September' is outside the desired time range. Skipping.
# News item 'Alibaba.com expands by helping former athletes become entrepreneurs' is outside the desired time range. Skipping.
# News item 'Alibaba to deploy AI-powered sourcing engine to boost online trade for global merchants' is outside the desired time range. Skipping.
# News item 'Best Stock to Buy Right Now: JD.com vs. Alibaba' is outside the desired time range. Skipping.
# News item 'Here's Why Alibaba (BABA) Fell More Than Broader Market' is outside the desired time range. Skipping.
# News item 'How to Buy ChatGPT Stocks in 2024' is outside the desired time range. Skipping.
# News item 'Alibaba: Buy, Sell, or Hold?' is outside the desired time range. Skipping.
# News item 'Wayfair Teams Up with Olympic Gold Medal Gymnast Shawn Johnson East in "House to Home" Series' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings Miss Estimates, Revenues Down Y/Y' is outside the desired time range. Skipping.
# News item 'Wayfair CEO flags alarming change in consumer behavior' is outside the desired time range. Skipping.
# News item 'Wayfair CEO Says Furniture Business Similar Now to Great Financial Crisis' is outside the desired time range. Skipping.
# News item 'Investing on interest rate cuts, jobless claims, auto loans: Wealth!' is outside the desired time range. Skipping.
# News item 'Wayfair Sales Fall. Home-Furnishings Decline Is Mirroring the ‘Great Financial Crisis.’' is outside the desired time range. Skipping.
# News item 'What e-commerce earnings may hint about consumer spending' is outside the desired time range. Skipping.
# News item 'Wayfair Quarterly Revenue Unexpectedly Falls Amid 'Unprecedented' Pullback in Consumer Spending' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings: Taking a Look at Key Metrics Versus Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Q2 Earnings and Revenues Lag Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair revenue down 1.7% in Q2 as category remains challenged' is outside the desired time range. Skipping.
# News item 'Wayfair (NYSE:W) Misses Q2 Revenue Estimates' is outside the desired time range. Skipping.
# News item 'Wayfair: Q2 Earnings Snapshot' is outside the desired time range. Skipping.
# News item 'Wayfair Announces Second Quarter 2024 Results, Reports Best Quarter of Profitability and Cash Flow in Three Years' is outside the desired time range. Skipping.
# News item 'Want Better Returns? Don't Ignore These 2 Retail-Wholesale Stocks Set to Beat Earnings' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Reports Q2: Everything You Need To Know Ahead Of Earnings' is outside the desired time range. Skipping.
# News item 'Analysts Estimate Coupang, Inc. (CPNG) to Report a Decline in Earnings: What to Look Out for' is outside the desired time range. Skipping.
# News item 'Countdown to Wayfair (W) Q2 Earnings: A Look at Estimates Beyond Revenue and EPS' is outside the desired time range. Skipping.
# News item 'Wayfair (W) Earnings Expected to Grow: Should You Buy?' is outside the desired time range. Skipping.
# News item 'Why Investors Need to Take Advantage of These 2 Retail-Wholesale Stocks Now' is outside the desired time range. Skipping.
# News item 'R1 RCM INC (RCM) Reports Q2 Earnings: What Key Metrics Have to Say' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc. (RCM) Reports Q2 Loss, Lags Revenue Estimates' is outside the desired time range. Skipping.
# News item 'R1 RCM Reports Second Quarter 2024 Results' is outside the desired time range. Skipping.
# News item 'Revenue cycle management firm R1 RCM to go private in $8.9B acquisition' is outside the desired time range. Skipping.
# News item 'Market Chatter: RBC, Deutsche Bank Plan US$4.5 Billion Debt Sale for R1 RCM buyout' is outside the desired time range. Skipping.
# News item 'Investment funds to take healthcare tech company R1 RCM private in nearly $9B deal' is outside the desired time range. Skipping.
# News item 'R1 to Go Private in $8.9 Billion Deal with TowerBrook, CD&R' is outside the desired time range. Skipping.
# News item 'R1 RCM to be Acquired by TowerBrook and CD&R for $8.9 Billion' is outside the desired time range. Skipping.
# News item 'R1 RCM Special Committee Provides Update on Evaluation of Strategic Alternatives' is outside the desired time range. Skipping.
# News item 'TowerBrook, CD&R in Advanced Talks to Make Offer for Health IT Firm R1 RCM' is outside the desired time range. Skipping.
# News item 'TowerBrook, CD&R Consider Joining Forces to Bid for R1 RCM' is outside the desired time range. Skipping.
# News item 'Merger-Arb Traders Bet on a Few Deals After Ugly Start of Year' is outside the desired time range. Skipping.
# News item 'R1 RCM to Release Second Quarter 2024 Results on August 7, 2024' is outside the desired time range. Skipping.
# News item 'New Mountain offers to acquire healthcare services provider R1 RCM' is outside the desired time range. Skipping.
# News item 'Stocks to Watch Tuesday: Tesla, Chewy, Nvidia' is outside the desired time range. Skipping.
# News item 'R1 RCM to Host a Virtual Event “Technology Teach-In: A Deep Dive into Key Focus Areas and the R1 Platform” on June 27, 2024' is outside the desired time range. Skipping.
# News item 'R1 RCM to Present at the 2024 Jefferies Global Healthcare Conference' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc. (NASDAQ:RCM) Q1 2024 Earnings Call Transcript' is outside the desired time range. Skipping.
# News item 'R1 RCM Inc (RCM) Q1 2024 Earnings Call Transcript Highlights: Navigating Challenges with Robust ...' is outside the desired time range. Skipping.
# News item 'Compared to Estimates, R1 RCM INC (RCM) Q1 Earnings: A Look at Key Metrics' is outside the desired time range. Skipping.
# News item 'LPH initiates sale process for Wingstop business in UK' is outside the desired time range. Skipping.
# News item 'Stocks eye the day's tech earnings, Etsy CEO: Market Domination' is outside the desired time range. Skipping.
# News item 'Wingstop is in 'a category of one': CEO talks expansion' is outside the desired time range. Skipping.
# News item 'WWE's SummerSlam to be filled with action - and lots of sponsors' is outside the desired time range. Skipping.
# News item 'Wingstop Second Quarter 2024 Earnings: Beats Expectations' is outside the desired time range. Skipping.
# News item 'Wingstop reports 70% jump in Q2 2024 net income' is outside the desired time range. Skipping.
# News item 'Wingstop cracks $2M AUV in another record-breaking quarter' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Q2 Earnings: How Key Metrics Compare to Wall Street Estimates' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Beats Q2 Earnings and Revenue Estimates' is outside the desired time range. Skipping.
# News item 'Wingstop (NASDAQ:WING) Beats Expectations in Strong Q2' is outside the desired time range. Skipping.
# News item 'Wingstop: Q2 Earnings Snapshot' is outside the desired time range. Skipping.
# News item 'Wingstop Inc. Reports Fiscal Second Quarter 2024 Financial Results' is outside the desired time range. Skipping.
# News item 'Are Retail-Wholesale Stocks Lagging  Urban Outfitters (URBN) This Year?' is outside the desired time range. Skipping.
# News item '6 Restaurant Stocks Eat McDonald's Lunch' is outside the desired time range. Skipping.
# News item '3 Restaurant Stocks to Buy and Hold for Great Long-Term Potential' is outside the desired time range. Skipping.
# News item 'Polen Capital U.S. SMID Company Growth Strategy Sold Wingstop (WING) After Share Price Appreciation' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) Reports Earnings Tomorrow: What To Expect' is outside the desired time range. Skipping.
# News item 'Artisan Small Cap Fund Trimmed Wingstop (WING) on Valuation Discipline' is outside the desired time range. Skipping.
# News item 'Wingstop (WING) to Post Q2 Earnings: What's in the Offing?' is outside the desired time range. Skipping.
# News item 'Seeking Clues to Wingstop (WING) Q2 Earnings? A Peek Into Wall Street Projections for Key Metrics' is outside the desired time range. Skipping.
# News item 'Instacart Stock Is Booming. Why It and Uber Are Defying Recession Fears.' is outside the desired time range. Skipping.
# News item 'Uber's Latest Results May Help 'Subdue' Consumer Slowdown Concerns, BofA Securities Says' is outside the desired time range. Skipping.
# News item 'Stock Market News for Aug 7, 2024' is outside the desired time range. Skipping.
# News item 'Lyft Shares Tank After Bookings and Outlook Miss Estimates' is outside the desired time range. Skipping.
# News item 'Lyft Q2 Earnings: Active Riders Increase 10%, Gross Bookings Surge 17%, Introduces Price Lock Feature' is outside the desired time range. Skipping.
# News item 'How Should You Play UBER Stock Following Q2 Earnings Beat?' is outside the desired time range. Skipping.
# News item 'ETFs to Buy as Uber Rallies Post Earnings Release' is outside the desired time range. Skipping.
# News item 'With 82% ownership, Uber Technologies, Inc. (NYSE:UBER) boasts of strong institutional backing' is outside the desired time range. Skipping.
# News item 'Q2 2024 Uber Technologies Inc Earnings Call' is outside the desired time range. Skipping.
# News item 'Recession outlook, tech trade, Zoetis CFO: Market Domination' is outside the desired time range. Skipping.
# News item 'S&P 500 Gains and Losses Today: Kenvue Soars on Band-Aid Maker's Strong Outlook' is outside the desired time range. Skipping.
# News item 'Why Is Uber Technologies, Inc. (UBER) the Best Travel and Leisure Stock to Buy According to Hedge Funds?' is outside the desired time range. Skipping.
# News item 'Uber Shares Jump as Company Returns to Profitability' is outside the desired time range. Skipping.
# News item 'Uber Stock Jumps As Earnings Return, Sales Growth Picks Up' is outside the desired time range. Skipping.
# News item 'Big Tech stocks: It's time to go bargain hunting, analyst says' is outside the desired time range. Skipping.
# News item 'Uber Freight EBITDA still in the red, and revenue continues to slide' is outside the desired time range. Skipping.
# News item 'How to navigate market volatility, buying a home: Wealth!' is outside the desired time range. Skipping.
# News item 'Stock movers: Nvidia rebounds; Uber, Palantir, Caterpillar up' is outside the desired time range. Skipping.
# News item 'UBER Q2 Earnings & Revenues Surpass Estimates, Up Y/Y' is outside the desired time range. Skipping.
# News item 'Top Stock Movers Now: Kenvue, Uber, Palantir, and More' is outside the desired time range. Skipping.
# No new news found at 2024-08-07 13:15:04 EDT
